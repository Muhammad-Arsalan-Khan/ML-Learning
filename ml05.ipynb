# %%
# Supervised Machine Learning
# K-Nearest_neighbors(KNN)

from sklearn.neighbors import KNeighborsClassifier

x = [
   [8.5, 120],  # Movie 1: Action (High rating, long)
   [7.9, 110],  # Movie 2: Action
   [6.1, 95],   # Movie 3: Comedy (Low rating, short)
   [6.5, 90],   # Movie 4: Comedy
   [8.0, 140],  # Movie 5: Drama (High rating, very long)
   [7.5, 130]   # Movie 6: Drama
]

y = ['Action', 'Action', 'Comedy', 'Comedy', 'Drama', 'Drama']

model = KNeighborsClassifier(n_neighbors=3)
model.fit(x, y)
movie_rating = float(input("Enter movie rating (0-10): "))
movie_length = float(input("Enter movie length in minutes: "))

movie_features = [[movie_rating, movie_length]]
predicted_genre = model.predict(movie_features)[0]
print(f"The predicted genre for the movie is: {predicted_genre}")
# Out:
# The predicted genre for the movie is: Action

# %% [markdown]
# Euclidean(Distance)
# Euclidean Distance do points ke darmiyan seedha (shortest) distance hota hai.
# K-Means mein har data point se centroid tak distance nikala jata hai. Jis centroid ka distance sabse kam hota hai, point usi cluster mein chala jata hai.
#
# formula --> distance = √(x2 - x1)**2 + (y2 - y1)**2
# example
# Point A = (2, 3)
# Point B = (5, 7)
# √(5 - 2)**2 + (7 - 3)**2  ans ---> 5
#
# euclidean sidi line hoti hain ak  point se dosre point ki ya areplane ki tarha distance cover karta hain

# %% [markdown]
# Manhattan Distance
# Isko City Block Distance bhi kehte hain.
# Ye diagonal nahi leta, sirf horizontal + vertical movement leta hai.
# manhattan ya horizontal or vertical distance conver karta hain ak point se dosre point ky darmiya jasy hum dai dhood lenay jaty hain
# formula d=∣x2​−x1​∣+∣y2​−y1​∣

# %% [markdown]
# Minkowski Distance
# ya dono do aagar ak sath jana ho is main hum p value 2 kary gay tu Euclidean ky kareeb value aye gi or 1 kary gay tu Manhattan ky kareeb value aye gi
# formula : d=( ∣x2​−x1​∣p + ∣y2​−y1​∣p ) 1/p

# %% [markdown]
# Hamming Distance
# ya NLP main kam ata hain
#
# Mostly use hota hai:
# Binary data
# Text comparison
# DNA sequence

# %% [markdown]
# hamming distance use for binary data
# euclidean distance use for continouse numerical data
# Manhattan distance use karo jb bola jaye question ya tb karo ya aksar tb use b hota jb euclidean se outliner pr effect kam rakhna  ho
# Minkowski ya b jb bola jaye Minkowski distance use karo tb karo or is se p value b control main hoti hain
#
# KNeighborsClassifier(n_neighbors=3, metric='yaha koi b distance a sakta hain or agar minkowski hain p ko define karna hoga ' p="like this")
